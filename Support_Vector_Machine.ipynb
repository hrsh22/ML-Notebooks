# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
plt.scatter(dataset['Age'],dataset['Purchased'])
plt.show()

# %%
plt.scatter(dataset['Gender'],dataset['Purchased'])
plt.show()

# %% [markdown]
# **Non-Linear Svm**

# %%
# Import packages to visualize the classifer
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import warnings

# Import packages to do the classifying
import numpy as np
from sklearn.svm import SVC

# Create Dataset
np.random.seed(0)
X_xor = np.random.randn(200, 2)
y_xor = np.logical_xor(X_xor[:, 0] > 0,
                       X_xor[:, 1] > 0)
y_xor = np.where(y_xor, 1, -1)

fig = plt.figure(figsize=(10,10))
plt.scatter(X_xor[y_xor == 1, 0],
            X_xor[y_xor == 1, 1],
            c='b', marker='x',
            label='1')
plt.scatter(X_xor[y_xor == -1, 0],
            X_xor[y_xor == -1, 1],
            c='r',
            marker='s',
            label='-1')

plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
# Create a SVC classifier using a linear kernel
svm = SVC(kernel='linear', C=1000, random_state=0)
# Train the classifier
svm.fit(X_xor, y_xor)

# Visualize the decision boundaries
fig = plt.figure(figsize=(10,10))
plot_decision_regions(X_xor, y_xor, clf=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %% [markdown]
# C is the cost associated with the wrong classification. The higher the value of C, the stricter the algorithm is to correctly separate the dataset. We usekernel='linear' for linear classifier.

# %% [markdown]
# sigma is a regulation parameter. The bigger sigma is, the less sensitive the classifier is to the difference in distance.

# %% [markdown]
# gamma is 1/sigma. Remember that sigma is a regulation function. Thus, the smaller the gamma is, the bigger the sigma is, and the less sensitive the classifier is to the distance between individual points.

# %%
# Create a SVC classifier using an RBF kernel
svm = SVC(kernel='rbf', random_state=0, gamma=1/100, C=1)
# Train the classifier
svm.fit(X_xor, y_xor)

# Visualize the decision boundaries
fig = plt.figure(figsize=(10,10))
plot_decision_regions(X_xor, y_xor, clf=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Create a SVC classifier using an RBF kernel
svm = SVC(kernel='rbf', random_state=0, gamma=1, C=1)
# Train the classifier
svm.fit(X_xor, y_xor)

# Visualize the decision boundaries
fig = plt.figure(figsize=(10,10))
plot_decision_regions(X_xor, y_xor, clf=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Create a SVC classifier using an RBF kernel
svm = SVC(kernel='rbf', random_state=0, gamma=1, C=10000)
# Train the classifier
svm.fit(X_xor, y_xor)

# Visualize the decision boundaries
fig = plt.figure(figsize=(10,10))
plot_decision_regions(X_xor, y_xor, clf=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
